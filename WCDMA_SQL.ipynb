# %%
import datetime
import adodbapi
adodbapi.adodbapi.verbose = True # adds details to the sample printout

# connection string templates from http://www.connectionstrings.com
# Switch test providers by changing the "if True" below

# connection string for an Access data table:
#mysql -D $db -u monitor9370user -h mysql.ndc.lucent.com --password=5525428 --con
#nect_timeout=5  -e "$1"


# connection string for an SQL server
_computername="135.1.121.42" #or name of computer with SQL Server
_databasename="monitorCust9370" #or something else
#_table_name= ''
_port="3306"

_username="monitor9370user"
_password='5525428'
        # this set opens a MS-SQL table with SQL authentication 
constr = r"Provider=SQLOLEDB;Initial Catalog=%s; Data Source=%s; User ID=%s; Password=%s; " \
% (_databasename, _computername, _username, _password)
#-----------------------
# Ths would work better with Windows Authentication then you would not need to expose your password.
    
#tell the server  we are not planning to update...
adodbapi.adodbapi.defaultIsolationLevel = adodbapi.adodbapi.adXactBrowse

#and we want a local cursor (so that we will have an accurate rowcount)
adodbapi.adodbapi.defaultCursorLocation = adodbapi.adodbapi.adUseClient

#create the connection
con = adodbapi.connect(constr)

#make a cursor on the connection
c = con.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-4668c53904e7> in <module>()
#      31
#      32 #create the connection
# ---> 33 con = adodbapi.connect(constr)
#      34
#      35 #make a cursor on the connection
#
# C:\Users\slbryson\AppData\Local\Continuum\Anaconda\lib\site-packages\adodbapi\adodbapi.pyc in connect(connection_string, timeout)
#     301         return Connection(c)
#     302     except (Exception), e:
# --> 303         raise OperationalError(e, "Error opening connection: " + connection_string)
#     304
#     305 # ------ DB API required module attributes ---------------------
#
# OperationalError: (com_error(-2147352567, 'Exception occurred.', (0, u'Microsoft OLE DB Provider for SQL Server', u'[DBNETLIB][ConnectionOpen (Connect()).]SQL Server does not exist or access denied.', None, 0, -2147467259), None), 'Error opening connection: Provider=SQLOLEDB;Initial Catalog=monitorCust9370; Data Source=135.1.121.42; User ID=monitor9370user; Password=5525428; ')
# adodbapi v2.4.3 attempting: "Provider=SQLOLEDB;Initial Catalog=monitorCust9370; Data Source=135.1.121.42; User ID=monitor9370user; Password=5525428; "

# %%
#run an SQL statement on the cursor
sql = 'select * from %s' % _table_name
print 'Executing the command: "%s"' % sql
c.execute(sql)

#check the results
print 'result rowcount shows as= %d. (Note: -1 means "not known")' \
      % (c.rowcount,)
print
print 'result data description is:'
print '            NAME TypeCd DispSize IntrnlSz Prec Scale Null?'
for d in c.description:
    print ('%16s %6d %8d %8d %4d %5d %5d') % d
print


#get the results
db = c.fetchmany(10)
kk = c.fetchall()
#Get RRC attempts
howmany = int(c.rowcount)
psrrc= np.zeros((howmany,1))
csrrc= np.zeros((howmany,1))
cellid = np.chararray((howmany,1), itemsize=20)
for rows in range(len(kk)):
    psrrc[rows] = kk[rows][3]
    lon[rows]= kk[rows][2]
    cellid[rows] = kk[rows][1]
#print them
if False:
    for rec in db:
        print repr(rec)
if False:
    print psrrc
psrrc =psrrc.tolist()
csrrc = csrrc.tolist()
cellid = cellid.tolist()
if False:
    print psrrc
c.close()
con.close()

# %%
import datetime
import numpy as np
""" db_print.py -- a simple demo for ADO database reads."""

import adodbapi
adodbapi.adodbapi.verbose = True # adds details to the sample printout

# connection string templates from http://www.connectionstrings.com
# Switch test providers by changing the "if True" below

# connection string for an Access data table:


# connection string for an SQL server
_computername="135.222.212.16" #or name of computer with SQL Server
_databasename="wms_kpi" #or something else
_table_name= 'dbo.skyhook'

_username="slbryson"
_password='marapr222!'
        # this set opens a MS-SQL table with SQL authentication 
constr = r"Provider=SQLOLEDB.1; Initial Catalog=%s; Data Source=%s; User ID=%s; Password=%s; " \
% (_databasename, _computername, _username, _password)
#-----------------------
# Ths would work better with Windows Authentication then you would not need to expose your password.
    
#tell the server  we are not planning to update...
adodbapi.adodbapi.defaultIsolationLevel = adodbapi.adodbapi.adXactBrowse

#and we want a local cursor (so that we will have an accurate rowcount)
adodbapi.adodbapi.defaultCursorLocation = adodbapi.adodbapi.adUseClient

#create the connection
con = adodbapi.connect(constr)

#make a cursor on the connection
c = con.cursor()

#run an SQL statement on the cursor
sql = 'select * from %s \
    where hour = 160' % _table_name
print 'Executing the command: "%s"' % sql
c.execute(sql)

#check the results
print 'result rowcount shows as = %d. (Note: -1 means "not known")' \
      % (c.rowcount,)
print
print 'result data description is:'
print '            NAME TypeCd DispSize IntrnlSz Prec Scale Null?'
for d in c.description:
    print ('%16s %6d %8d %8d %4d %5d %5d') % d
print
print 'result first ten records are:' 

#get the results
db = c.fetchmany(10)

#print 
if True:
 for rec in db:
    print repr(rec)
    
c.close()
con.close()
# Out:
# adodbapi v2.4.3 attempting: "Provider=SQLOLEDB.1; Initial Catalog=wms_kpi; Data Source=135.222.212.16; User ID=slbryson; Password=marapr222!; "
# adodbapi New connection at 5238208
# adodbapi New cursor at 506A7B8 on conn 5238208
# Executing the command: "select * from dbo.skyhook     where hour = 160"
# Executing command="select * from dbo.skyhook     where hour = 160"
# result rowcount shows as = 2625. (Note: -1 means "not known")
# result data description is:
#             NAME TypeCd DispSize IntrnlSz Prec Scale Null?
#             date    200       10       80  255   255     0
#           tileID    200       10       80  255   255     0
#             hour      3        4        4   10   255     0
#            count      3        4        4   10   255     0
#          avg_lat      5        8        8   15   255     0
#         avg_long      5        8        8   15   255     0
#          min_lat      5        8        8   15   255     0
#         min_long      5        8        8   15   255     0
#          max_lat      5        8        8   15   255     0
#         max_long      5        8        8   15   255     0
#
# result first ten records are:
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D20BC10', hour:160, count:6, avg_lat:34.04308319091797, avg_long:-118.45205688476562, min_lat:34.04296875, min_long:-118.4521484375, max_lat:34.043212890625, max_long:-118.451904296875}>
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D23214E', hour:160, count:5, avg_lat:34.0018424987793, avg_long:-118.2766342163086, min_lat:34.001708984375, min_long:-118.27685546875, max_lat:34.001953125, max_long:-118.276611328125}>
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D23214F', hour:160, count:4, avg_lat:34.00182342529297, avg_long:-118.27655029296875, min_lat:34.001708984375, min_long:-118.276611328125, max_lat:34.001953125, max_long:-118.2763671875}>
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D264DCB', hour:160, count:2, avg_lat:34.09331130981445, avg_long:-118.37016296386719, min_lat:34.09326171875, min_long:-118.370361328125, max_lat:34.093505859375, max_long:-118.3701171875}>
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D264DD8', hour:160, count:10, avg_lat:34.093345642089844, avg_long:-118.37004852294922, min_lat:34.09326171875, min_long:-118.3701171875, max_lat:34.093505859375, max_long:-118.369873046875}>
# <SQLrow={date:u'2014-02-02', tileid:u'AE9D264DD9', hour:160, count:3, avg_lat:34.09342956542969, avg_long:-118.3697509765625, min_lat:34.09326171875, min_long:-118.369873046875, max_lat:34.093505859375, max_long:-118.36962890625}>
# <SQLrow={date:u'2014-02-08', tileid:u'AD35AF9C73', hour:160, count:2, avg_lat:33.73166275024414, avg_long:-118.29303741455078, min_lat:33.7314453125, min_long:-118.293212890625, max_lat:33.731689453125, max_long:-118.29296875}>
# <SQLrow={date:u'2014-02-08', tileid:u'AD35AF9D40', hour:160, count:1, avg_lat:33.731658935546875, avg_long:-118.29273223876953, min_lat:33.7314453125, min_long:-118.29296875, max_lat:33.731689453125, max_long:-118.292724609375}>
# <SQLrow={date:u'2014-02-08', tileid:u'AD35AF9D41', hour:160, count:1, avg_lat:33.731658935546875, avg_long:-118.29271697998047, min_lat:33.7314453125, min_long:-118.292724609375, max_lat:33.731689453125, max_long:-118.29248046875}>
# <SQLrow={date:u'2014-02-08', tileid:u'AD35AF9D44', hour:160, count:15, avg_lat:33.73173522949219, avg_long:-118.29280853271484, min_lat:33.731689453125, min_long:-118.29296875, max_lat:33.73193359375, max_long:-118.292724609375}>
# adodbapi Closed connection at 5238208
